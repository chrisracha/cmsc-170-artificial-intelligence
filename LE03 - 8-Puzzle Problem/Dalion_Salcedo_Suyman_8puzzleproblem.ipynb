# %% [markdown]
# ### CMSC 170: Laboratory Exercise 3
# ##### The 8-Puzzle Problem
# * Dalion, Adrian Lloyd
# * Salcedo, Chris Samuel
# * Suyman, Ann Junah

# %% [markdown]
# #### Task 1.A: Define the Problem
#
# ##### 1. What is the problemt that needs a solution?
#
# The 8-puzzle problem is a sliding puzzle that consists of 8-numbered tiles, labeled 1-8, and an empty space in a 3x3 grid. The challenge is rearranging the tiles through that empty space to achieve a specific goal state.
#
# ##### 2. What is the initial state?
#
# The initial state is any valid state/configuration of the problem, serving as the starting point to where the problem-solving begins.
#
# ##### 3. What is the goal state?
#
# The goal state is the desired state/configuration that is to be achieved. The most common goal state is the numerically arranged state [[1,2,3],[4,5,6],[7,8,0]].
#
# ##### 4. What are the valid actions?
# The valid actions consist of four moves, representing the moves of the tiles into the empty space.
#
# * UP: Move the tile below the empty space upward.
# * DOWN: Move the tile above the empty space doenward
# * LEFT: Move the tile on the right of the empty space to the left
# * RIGHT: Move the tile on the left of the empty space to the right
#
# Of course, the validity of a move or an action relies on the current condition of the empty space. If the empty space is located in a side or corner of the grid then there will not be enough tiles arround it to fullfill the allowability of the four listed moves.
#
# ##### 5. Whatis/are the functions that validate whether a state is valid?
#
# State validation check include constraints where,
# 1. The board should only contain exactly 8 numbered tiles and one empty space
# 2. All tiles are within the 3x3 boundaries
# 3. No duplicate numbers exist, and
# 4. The state is reachable from the initial state
#
# #### References:
# * https://www.geeksforgeeks.org/dsa/8-puzzle-problem-using-branch-and-bound/

# %% [markdown]
# #### Task 1.B: Define the Breadth-First Search
#
# ##### 1. What is the main idea behind the breadth-first search (BFS) algorithm, and how does it explore a graph or tree?
#
# The Breadth-First Search (BFS) is a search algorithm that explores nodes by level, starting from the root note, visiting all nodes at depth `d` before exploring nodes `d+1`. In the current puzzle, the algorithm explores all possible moves from the current state before moving to states that require more moves. This way, the shortest possible path is guaranteed to be outputted.
#
# ##### 2. What data structure does BFS use, and why is it important? How does BFS differ from depth-first search (DFS)?
#
# BFS uses a queue (FIFO) data structure to ensure that nodes are processed in the order they were discovered and therefore guaranteeing level-by-level exploration. On the other hand, DFS uses stack (LIFO) and explores more depth-wise (hence the name), which although may find a solution that is not the most optimized, it is better memory-wise. BFS is used mostly on problems such as bipartite graphs and shortest paths, while DFS shows its strengths on problems such as acyclic graphs and finding strongly connected components.
#
# #### 3. What is the time complexity of BFS for a graph with V vertices and E edges?
#
# The time complexity of BFS is O(V+E) while its space complexity is O(V) for storing the queue and visited states.
#
# #### References:
# * https://www.geeksforgeeks.org/dsa/breadth-first-search-or-bfs-for-a-graph/
# * https://www.geeksforgeeks.org/dsa/difference-between-bfs-and-dfs/

# %% [markdown]
# #### Task 2: 8-Puzzle Game in Python

# %%
from typing import List, Tuple, Optional
import copy
from IPython.display import clear_output

# %%
# core 8-puzzle problem definition
class EightPuzzle:
    # represents the 8-puzzle problem with state validation and action generation.
    
    def __init__(self, initial_state: Optional[List[List[int]]] = None, goal_state: Optional[List[List[int]]] = None):
        # initialize with default states if none provided
        self.initial_state = initial_state or [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
        self.goal_state = goal_state or [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
    
    def is_valid_state(self, state: List[List[int]]) -> bool:
        # check if state is a proper 3x3 configuration with numbers 0-8
        if not state or len(state) != 3:
            return False
        
        flat_state = []
        for row in state:
            if len(row) != 3:
                return False
            flat_state.extend(row)
        
        return sorted(flat_state) == list(range(9))
    
    def find_empty_position(self, state: List[List[int]]) -> Optional[Tuple[int, int]]:
        # find the position of the empty space (0)
        for i in range(3):
            for j in range(3):
                if state[i][j] == 0:
                    return (i, j)
        return None
    
    def get_valid_actions(self, state: List[List[int]]) -> List[str]:
        # get all possible moves from the current state
        empty_pos = self.find_empty_position(state)
        if not empty_pos:
            return []
        
        row, col = empty_pos
        valid_actions = []
        
        # define possible moves and their direction offsets
        moves = {
            'up': (1, 0),
            'down': (-1, 0),
            'left': (0, 1),
            'right': (0, -1)
        }
        
        for action, (dr, dc) in moves.items():
            new_row, new_col = row + dr, col + dc
            if 0 <= new_row < 3 and 0 <= new_col < 3:
                valid_actions.append(action)
        
        return valid_actions
    
    def apply_action(self, state: List[List[int]], action: str) -> Optional[List[List[int]]]:
        # apply a move to the state and return the new state
        empty_pos = self.find_empty_position(state)
        if not empty_pos:
            return None
        
        row, col = empty_pos
        new_state = [row[:] for row in state]  # deep copy
        
        moves = {
            'up': (1, 0),
            'down': (-1, 0),
            'left': (0, 1),
            'right': (0, -1)
        }
        
        if action in moves:
            dr, dc = moves[action]
            new_row, new_col = row + dr, col + dc
            
            if 0 <= new_row < 3 and 0 <= new_col < 3:
                # swap empty space with adjacent tile
                new_state[row][col] = new_state[new_row][new_col]
                new_state[new_row][new_col] = 0
                return new_state
        
        return None
    
    def is_goal_state(self, state: List[List[int]]) -> bool:
        # check if the current state matches the goal state
        return state == self.goal_state
    
    def is_solvable(self) -> bool:
        # check if the puzzle is solvable using inversion count
        def count_inversions(state: List[List[int]]) -> int:
            flat_state = [num for row in state for num in row if num != 0]
            inversions = 0
            for i in range(len(flat_state)):
                for j in range(i + 1, len(flat_state)):
                    if flat_state[i] > flat_state[j]:
                        inversions += 1
            return inversions
        
        initial_inversions = count_inversions(self.initial_state)
        goal_inversions = count_inversions(self.goal_state)
        
        # for 3x3 puzzle, solvability depends on inversion parity
        return (initial_inversions % 2) == (goal_inversions % 2)
    
    def display_state(self, state: List[List[int]], title: str = "state"):
        # display the state in a formatted way
        print(f"\n{title}:")
        print("┌─────┬─────┬─────┐")
        for i, row in enumerate(state):
            row_str = "│"
            for num in row:
                if num == 0:
                    row_str += "     │"
                else:
                    row_str += f"  {num}  │"
            print(row_str)
            if i < 2:
                print("├─────┼─────┼─────┤")
        print("└─────┴─────┴─────┘")

# %%
# interactive game extending the core problem
class EightPuzzleGame(EightPuzzle):
    
    def __init__(self):
        super().__init__()
        self.current_state = None
        self.moves_count = 0
    
    def display_instructions(self):
        # display game instructions
        print()
        print("8-Puzzle Game Start")
        print()
        print("\nThe 8-puzzle problem is a 3x3 board with 8 tiles numbered from 1 to 8")
        print("and one empty space (represented by 0).")
        print("\nThe objective is to begin with an arbitrary configuration of tiles,")
        print("and move them to place the numbered tiles to match the final configuration.")
        print("\nRules:")
        print("1. Input the initial state of the puzzle using this format:")
        print("   [1,2,3,4,0,8,5,6,7] (where 0 represents the empty space)")
        print("\n2. Use the following keys to move tiles into the empty space:")
        print("   'W' or 'w' → move tile up into empty space")
        print("   'S' or 's' → move tile down into empty space") 
        print("   'A' or 'a' → move tile left into empty space")
        print("   'D' or 'd' → move tile right into empty space")
        print("   'Q' or 'q' → quit the game")
        print()
    
    def setup_initial_state(self) -> bool:
        # get and validate initial state from user input
        while True:
            try:
                print("\nEnter the initial state of the puzzle:")
                user_input = input("Format: [1,2,3,4,0,8,5,6,7] → ")
                
                # parse input
                numbers = eval(user_input)
                if len(numbers) != 9:
                    raise ValueError("Must contain exactly 9 elements")
                
                # convert to 3x3 board
                board = [numbers[i:i+3] for i in range(0, 9, 3)]
                
                if self.is_valid_state(board):
                    self.initial_state = board
                    self.current_state = [row[:] for row in board]  # deep copy
                    self.display_state(self.current_state, "initial state")
                    return True
                else:
                    print("Invalid state! Please ensure you have numbers 0-8 with no duplicates.")
                    
            except Exception as e:
                print(f"Invalid input format! Error: {e}")
                print("Please use the format: [1,2,3,4,0,8,5,6,7]")
    
    def make_move(self, user_input: str) -> bool:
        # process user input and make a move if valid
        key_to_action = {'w': 'up', 's': 'down', 'a': 'left', 'd': 'right'}
        action = key_to_action.get(user_input.lower())
        
        if action:
            new_state = self.apply_action(self.current_state, action)
            if new_state:
                self.current_state = new_state
                self.moves_count += 1
                return True
        
        return False
    
    def play_game(self):
        # main interactive game loop
        self.display_instructions()
        
        if not self.setup_initial_state():
            return
        
        print("\nGoal state:")
        self.display_state(self.goal_state)
        
        while not self.is_goal_state(self.current_state):
            
            move = input("\nEnter your move: ").strip()
            
            if move.lower() == 'q':
                print("Thanks for playing! Goodbye!")
                break
            
            if self.make_move(move):
                clear_output(wait=True)
                print(f"\nMove {self.moves_count} completed!")
                self.display_state(self.current_state, f"Current state (move {self.moves_count})")
                
                if self.is_goal_state(self.current_state):
                    print("\nCongratulations!")
                    print(f"You solved the puzzle in {self.moves_count} moves!")
                    print("Goal state reached!")
                    break
            else:
                print("Invalid move! Please try again.")

# %% [markdown]
# #### Run to play the game

# %%
game = EightPuzzleGame()
game.play_game()
# Out:
# 8-Puzzle Game Start
#
#
# The 8-puzzle problem is a 3x3 board with 8 tiles numbered from 1 to 8
# and one empty space (represented by 0).
#
# The objective is to begin with an arbitrary configuration of tiles,
# and move them to place the numbered tiles to match the final configuration.
#
# Rules:
# 1. Input the initial state of the puzzle using this format:
#    [1,2,3,4,0,8,5,6,7] (where 0 represents the empty space)
#
# 2. Use the following keys to move tiles into the empty space:
#    'W' or 'w' → move tile up into empty space
#    'S' or 's' → move tile down into empty space
#    'A' or 'a' → move tile left into empty space
#    'D' or 'd' → move tile right into empty space
#    'Q' or 'q' → quit the game
#
#
# Enter the initial state of the puzzle:
# Format: [1,2,3,4,0,8,5,6,7] →  [1,2,0,4,5,3,7,8,6]
# initial state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │     │
# ├─────┼─────┼─────┤
# │  4  │  5  │  3  │
# ├─────┼─────┼─────┤
# │  7  │  8  │  6  │
# └─────┴─────┴─────┘
#
# Goal state:
#
# state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
# Enter your move:  w
# Move 1 completed!
#
# Current state (move 1):
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │     │
# ├─────┼─────┼─────┤
# │  7  │  8  │  6  │
# └─────┴─────┴─────┘
# Enter your move:  w
# Move 2 completed!
#
# Current state (move 2):
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
#
# Congratulations!
# You solved the puzzle in 2 moves!
# Goal state reached!

# %% [markdown]
# #### Task 3: Breadth-First Search (BFS) in Python

# %%
from collections import deque
from typing import Set, Dict, Any, Optional, Tuple, List
import time

# %%
class SearchNode:
    # represents a node in the search tree.
    # generic node class that can be used with any search problem.
    
    def __init__(self, state: Any, parent: Optional['SearchNode'] = None, 
                 action: Optional[str] = None, depth: int = 0, path_cost: int = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.depth = depth
        self.path_cost = path_cost
    
    def __eq__(self, other) -> bool:
        # check if two nodes have the same state
        return self.state == other.state if isinstance(other, SearchNode) else False
    
    def __hash__(self) -> int:
        # make node hashable for use in sets
        return hash(str(self.state))
    
    def get_solution_path(self) -> List[Tuple[Any, str]]:
        # get the path from root to this node
        path = []
        current = self
        while current:
            if current.action:
                path.append((current.state, current.action))
            else:
                path.append((current.state, "initial state"))
            current = current.parent
        return path[::-1]  # reverse to get path from root to current

# %%
class BreadthFirstSearch:
    # generic breadth-first search algorithm.
    # can work with any problem class that implements the required interface.
    
    def __init__(self, problem: Any):
        self.problem = problem
        self.statistics = {
            'nodes_explored': 0,
            'nodes_generated': 0,
            'max_frontier_size': 0,
            'time_taken': 0.0,
            'solution_length': -1
        }
    
    def state_to_key(self, state: Any) -> Tuple:
        # convert state to hashable key for duplicate detection
        if isinstance(state, list):
            return tuple(tuple(row) if isinstance(row, list) else row for row in state)
        return tuple(state) if hasattr(state, '__iter__') else state
    
    def search(self, verbose: bool = True) -> Tuple[Optional[SearchNode], Dict[str, Any]]:
        start_time = time.time()
        
        # initialize with root node
        root_node = SearchNode(self.problem.initial_state)
        
        # check if initial state is goal
        if self.problem.is_goal_state(root_node.state):
            self.statistics['time_taken'] = time.time() - start_time
            self.statistics['solution_length'] = 0
            return root_node, self.statistics
        
        # initialize frontier (queue) and explored set
        frontier = deque([root_node])
        explored = set()
        frontier_states = {self.state_to_key(root_node.state)}
        
        self.statistics['nodes_generated'] = 1
        self.statistics['max_frontier_size'] = 1
        
        if verbose:
            print("BFS Initiated")
            print(f"Initial state: {self.problem.initial_state}")
            print(f"Goal state: {self.problem.goal_state}")
            print()
        
        while frontier:
            # update frontier size tracking
            current_frontier_size = len(frontier)
            if current_frontier_size > self.statistics['max_frontier_size']:
                self.statistics['max_frontier_size'] = current_frontier_size
            
            # remove node from frontier (fifo)
            current_node = frontier.popleft()
            current_state_key = self.state_to_key(current_node.state)
            frontier_states.discard(current_state_key)
            
            # add to explored set
            explored.add(current_state_key)
            self.statistics['nodes_explored'] += 1
            
            if verbose and self.statistics['nodes_explored'] % 100 == 0:
                print(f"Nodes explored: {self.statistics['nodes_explored']}, "
                      f"Frontier size: {len(frontier)}")
            
            # expand current node
            valid_actions = self.problem.get_valid_actions(current_node.state)
            
            for action in valid_actions:
                child_state = self.problem.apply_action(current_node.state, action)
                if child_state is None:
                    continue
                
                child_state_key = self.state_to_key(child_state)
                
                # skip if already explored or in frontier
                if child_state_key in explored or child_state_key in frontier_states:
                    continue
                
                # create child node
                child_node = SearchNode(
                    state=child_state,
                    parent=current_node,
                    action=action,
                    depth=current_node.depth + 1,
                    path_cost=current_node.path_cost + 1
                )
                
                self.statistics['nodes_generated'] += 1
                
                # goal test
                if self.problem.is_goal_state(child_state):
                    self.statistics['time_taken'] = time.time() - start_time
                    self.statistics['solution_length'] = child_node.depth
                    
                    if verbose:
                        print("\nsolution found!")
                        print(f"Solution length: {child_node.depth} moves")
                        print(f"Nodes explored: {self.statistics['nodes_explored']}")
                        print(f"Nodes generated: {self.statistics['nodes_generated']}")
                        print(f"Time taken: {self.statistics['time_taken']:.4f} seconds")
                    
                    return child_node, self.statistics
                
                # add to frontier
                frontier.append(child_node)
                frontier_states.add(child_state_key)
        
        # no solution found
        self.statistics['time_taken'] = time.time() - start_time
        
        if verbose:
            print("No solution found!")
            print(f"Nodes explored: {self.statistics['nodes_explored']}")
        
        return None, self.statistics
    
    def print_solution_path(self, solution_node: Optional[SearchNode]):
        # print the complete solution path
        if not solution_node:
            print("No solution to display")
            return
        
        path = solution_node.get_solution_path()
        
        print()
        print("Complete solution path")
        print()
        
        for i, (state, action) in enumerate(path):
            if hasattr(self.problem, 'display_state'):
                self.problem.display_state(state, f"Step {i}: {action}")
            else:
                print(f"Step {i}: {action}")
                print(f"State: {state}")
            
            if i < len(path) - 1:
                print("↓")
        
        print(f"\nTotal moves to reach goal: {len(path) - 1}")

# %% [markdown]
# #### Task 3: Breadth-First Search (BFS) for the 8-Puzzle Problem

# %%
import os
from typing import list, optional, dict, any

# %%
import time
from typing import List

class EightPuzzleBFS:
    # specialized solver that combines 8-puzzle problem with bfs algorithm.
    # handles file i/o and provides comprehensive solving capabilities.
    
    def __init__(self):
        self.problem = EightPuzzle()
        self.bfs = None
        self.solution = None
        self.statistics = None
    
    def read_from_file(self, filename: str) -> bool:
        # read initial and goal states from file
        try:
            with open(filename, 'r') as file:
                lines = [line.strip() for line in file.readlines() if line.strip()]
            
            if len(lines) < 6:
                raise ValueError("File must contain at least 6 lines")
            
            # parse initial state (first 3 lines)
            initial_state: List[List[int]] = []
            for i in range(3):
                row = [int(x.strip()) for x in lines[i].split(',')]
                if len(row) != 3:
                    raise ValueError(f"Row {i+1} must have exactly 3 numbers")
                initial_state.append(row)
            
            # parse goal state (next 3 lines)
            goal_state: List[List[int]] = []
            for i in range(3, 6):
                row = [int(x.strip()) for x in lines[i].split(',')]
                if len(row) != 3:
                    raise ValueError(f"Row {i-2} must have exactly 3 numbers")
                goal_state.append(row)
            
            # validate states
            if not (self.problem.is_valid_state(initial_state) and 
                    self.problem.is_valid_state(goal_state)):
                raise ValueError("Invalid puzzle states in file.")
            
            self.problem.initial_state = initial_state
            self.problem.goal_state = goal_state
            
            print(f"Successfully loaded puzzle from '{filename}'")
            return True
            
        except FileNotFoundError:
            print(f"Error: file '{filename}' not found!")
            return False
        except Exception as e:
            print(f"Error reading file: {e}")
            return False
    
    
    def solve_puzzle(self, verbose: bool = True) -> bool:
        # solve the loaded puzzle using bfs
        if not self.problem.initial_state or not self.problem.goal_state:
            print("No puzzle loaded! Please load a puzzle first.")
            return False
        
        # check solvability
        if not self.problem.is_solvable():
            print("This puzzle configuration is not solvable.")
            print("The initial and goal states have different inversion parity.")
            return False
        
        if verbose:
            print("\nPuzzle analysis")
            self.problem.display_state(self.problem.initial_state, "Initial state")
            self.problem.display_state(self.problem.goal_state, "Goal state")
            print("Solvable: yes")
        
        # create and run bfs solver
        self.bfs = BreadthFirstSearch(self.problem)
        self.solution, self.statistics = self.bfs.search(verbose=verbose)
        
        return self.solution is not None
    
    def display_solution(self):
        # display the complete solution with detailed output
        if not self.solution:
            print("No solution to display. Run solve_puzzle() first.")
            return
        
        print("\nSolution found!\n")
        
        # print solution path
        self.bfs.print_solution_path(self.solution)
        
        # print detailed statistics
        print("\nDetailed performance analysis\n")
        print("Solution quality:")
        print(f"  • Moves to goal: {self.statistics['solution_length']}")
        
        print("\nSearch efficiency:")
        print(f"  • Nodes explored: {self.statistics['nodes_explored']}")
        print(f"  • Nodes generated: {self.statistics['nodes_generated']}")
        
        print("\nMemory usage:")
        print(f"  • Max frontier size: {self.statistics['max_frontier_size']}")
        
        print("\nTime performance:")
        print(f"  • Execution time: {self.statistics['time_taken']:.4f} seconds")
        
        if self.statistics['nodes_explored'] > 0:
            branching_factor = self.statistics['nodes_generated'] / self.statistics['nodes_explored']
            print("\nSearch tree analysis:")
            print(f"  • Avg branching factor: {branching_factor:.2f}")
            print(f"  • Tree depth: {self.statistics['solution_length']}")
    
    def run_interactive_mode(self):
        # interactive solver with menu system
        print("8-Puzzle BFS solver")
        print("Combining modular 8-puzzle problem with generic BFS algorithm.")
        
        try:
            while True:
                print("\nMenu options:")
                print("1. Load puzzle from file")
                print("2. Manual puzzle input") 
                print("3. Solve current puzzle")
                print("4. View solution details")
                print("5. Exit")
                
                choice = input("\nEnter choice (1-5): ").strip()
                
                if choice == '1':
                    filename = input("Enter filename: ").strip()
                    self.read_from_file(filename)
                
                elif choice == '2':
                    self.manual_input()
                
                elif choice == '3':
                    if self.solve_puzzle():
                        print("\nPuzzle solved successfully.")
                        print("Use option 4 to view detailed solution.")
                    else:
                        print("\nCould not solve puzzle.")
                
                elif choice == '4':
                    self.display_solution()
                
                elif choice == '5':
                    print("Thank you for using the 8-puzzle solver. Goodbye.")
                    break
                
                else:
                    print("Invalid choice. Please enter a number from 1 to 5.")
        except KeyboardInterrupt:
            print("\nInteractive session cancelled by user.")
    
    def manual_input(self):
        # manual input interface for puzzle states
        print("\nManual puzzle input")
        print("Enter each row as comma-separated values (e.g., 1,2,3). Use 0 to represent the empty space.")
        
        try:
            # input initial state
            print("\nInitial state:")
            initial_state: List[List[int]] = []
            for i in range(3):
                while True:
                    try:
                        row_input = input(f"  row {i+1}: ").strip()
                        row = [int(x.strip()) for x in row_input.split(',')]
                        if len(row) != 3:
                            print("  Please enter exactly 3 numbers.")
                            continue
                        initial_state.append(row)
                        break
                    except ValueError:
                        print("  Please enter valid integers separated by commas.")
            
            # input goal state  
            print("\nGoal state:")
            goal_state: List[List[int]] = []
            for i in range(3):
                while True:
                    try:
                        row_input = input(f"  row {i+1}: ").strip()
                        row = [int(x.strip()) for x in row_input.split(',')]
                        if len(row) != 3:
                            print("  Please enter exactly 3 numbers.")
                            continue
                        goal_state.append(row)
                        break
                    except ValueError:
                        print("  Please enter valid integers separated by commas.")
            
            # validate states
            if not (self.problem.is_valid_state(initial_state) and 
                    self.problem.is_valid_state(goal_state)):
                print("Invalid puzzle states. Each must contain numbers 0-8 exactly once.")
                return
            
            self.problem.initial_state = initial_state
            self.problem.goal_state = goal_state
            
            print("\nPuzzle states accepted.")
            self.problem.display_state(initial_state, "Entered initial state")
            self.problem.display_state(goal_state, "Entered goal state")
            
        except KeyboardInterrupt:
            print("\nInput cancelled.")

# %%
solve = EightPuzzleBFS()
solve.run_interactive_mode()
# Out:
# 8-Puzzle BFS solver
# Combining modular 8-puzzle problem with generic BFS algorithm.
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  1
# Enter filename:  easy_puzzle.txt
# Successfully loaded puzzle from 'easy_puzzle.txt'
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  3
# Puzzle analysis
#
# Initial state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │     │  6  │
# ├─────┼─────┼─────┤
# │  7  │  5  │  8  │
# └─────┴─────┴─────┘
#
# Goal state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
# Solvable: yes
# BFS Initiated
# Initial state: [[1, 2, 3], [4, 0, 6], [7, 5, 8]]
# Goal state: [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
#
#
# solution found!
# Solution length: 2 moves
# Nodes explored: 2
# Nodes generated: 6
# Time taken: 0.0001 seconds
#
# Puzzle solved successfully.
# Use option 4 to view detailed solution.
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  4
# Solution found!
#
#
# Complete solution path
#
#
# Step 0: initial state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │     │  6  │
# ├─────┼─────┼─────┤
# │  7  │  5  │  8  │
# └─────┴─────┴─────┘
# ↓
#
# Step 1: up:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │     │  8  │
# └─────┴─────┴─────┘
# ↓
#
# Step 2: left:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
#
# Total moves to reach goal: 2
#
# Detailed performance analysis
#
# Solution quality:
#   • Moves to goal: 2
#   • Optimality: guaranteed (bfs finds the shortest path)
#
# Search efficiency:
#   • Nodes explored: 2
#   • Nodes generated: 6
#
# Memory usage:
#   • Max frontier size: 4
#
# Time performance:
#   • Execution time: 0.0001 seconds
#
# Search tree analysis:
#   • Avg branching factor: 3.00
#   • Tree depth: 2
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  1
# Enter filename:  medium_puzzle.txt
# Successfully loaded puzzle from 'medium_puzzle.txt'
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  3
# Puzzle analysis
#
# Initial state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │     │  6  │  8  │
# ├─────┼─────┼─────┤
# │  4  │  7  │  5  │
# └─────┴─────┴─────┘
#
# Goal state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
# Solvable: yes
# BFS Initiated
# Initial state: [[1, 2, 3], [0, 6, 8], [4, 7, 5]]
# Goal state: [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
#
#
# solution found!
# Solution length: 7 moves
# Nodes explored: 69
# Nodes generated: 117
# Time taken: 0.0010 seconds
#
# Puzzle solved successfully.
# Use option 4 to view detailed solution.
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  4
# Solution found!
#
#
# Complete solution path
#
#
# Step 0: initial state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │     │  6  │  8  │
# ├─────┼─────┼─────┤
# │  4  │  7  │  5  │
# └─────┴─────┴─────┘
# ↓
#
# Step 1: up:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  6  │  8  │
# ├─────┼─────┼─────┤
# │     │  7  │  5  │
# └─────┴─────┴─────┘
# ↓
#
# Step 2: left:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  6  │  8  │
# ├─────┼─────┼─────┤
# │  7  │     │  5  │
# └─────┴─────┴─────┘
# ↓
#
# Step 3: left:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  6  │  8  │
# ├─────┼─────┼─────┤
# │  7  │  5  │     │
# └─────┴─────┴─────┘
# ↓
#
# Step 4: down:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  6  │     │
# ├─────┼─────┼─────┤
# │  7  │  5  │  8  │
# └─────┴─────┴─────┘
# ↓
#
# Step 5: right:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │     │  6  │
# ├─────┼─────┼─────┤
# │  7  │  5  │  8  │
# └─────┴─────┴─────┘
# ↓
#
# Step 6: up:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │     │  8  │
# └─────┴─────┴─────┘
# ↓
#
# Step 7: left:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
#
# Total moves to reach goal: 7
#
# Detailed performance analysis
#
# Solution quality:
#   • Moves to goal: 7
#   • Optimality: guaranteed (bfs finds the shortest path)
#
# Search efficiency:
#   • Nodes explored: 69
#   • Nodes generated: 117
#
# Memory usage:
#   • Max frontier size: 48
#
# Time performance:
#   • Execution time: 0.0010 seconds
#
# Search tree analysis:
#   • Avg branching factor: 1.70
#   • Tree depth: 7
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  1
# Enter filename:  hard_puzzle.txt
# Successfully loaded puzzle from 'hard_puzzle.txt'
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  3
# Puzzle analysis
#
# Initial state:
# ┌─────┬─────┬─────┐
# │  8  │  6  │  7  │
# ├─────┼─────┼─────┤
# │  2  │  5  │  4  │
# ├─────┼─────┼─────┤
# │  3  │     │  1  │
# └─────┴─────┴─────┘
#
# Goal state:
# ┌─────┬─────┬─────┐
# │  1  │  2  │  3  │
# ├─────┼─────┼─────┤
# │  4  │  5  │  6  │
# ├─────┼─────┼─────┤
# │  7  │  8  │     │
# └─────┴─────┴─────┘
# Solvable: yes
# BFS Initiated
# Initial state: [[8, 6, 7], [2, 5, 4], [3, 0, 1]]
# Goal state: [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
#
# Nodes explored: 100, Frontier size: 75
# Nodes explored: 200, Frontier size: 121
# Nodes explored: 300, Frontier size: 203
# Nodes explored: 400, Frontier size: 255
# Nodes explored: 500, Frontier size: 282
# Nodes explored: 600, Frontier size: 369
# Nodes explored: 700, Frontier size: 458
# Nodes explored: 800, Frontier size: 540
# Nodes explored: 900, Frontier size: 566
# Nodes explored: 1000, Frontier size: 610
# Nodes explored: 1100, Frontier size: 648
# Nodes explored: 1200, Frontier size: 683
# Nodes explored: 1300, Frontier size: 729
# Nodes explored: 1400, Frontier size: 817
# Nodes explored: 1500, Frontier size: 905
# Nodes explored: 1600, Frontier size: 993
# Nodes explored: 1700, Frontier size: 1080
# Nodes explored: 1800, Frontier size: 1163
# Nodes explored: 1900, Frontier size: 1245
# Nodes explored: 2000, Frontier size: 1326
# Nodes explored: 2100, Frontier size: 1368
# Nodes explored: 2200, Frontier size: 1408
# Nodes explored: 2300, Frontier size: 1448
# Nodes explored: 2400, Frontier size: 1478
# Nodes explored: 2500, Frontier size: 1512
# Nodes explored: 2600, Frontier size: 1546
# Nodes explored: 2700, Frontier size: 1580
# Nodes explored: 2800, Frontier size: 1609
# Nodes explored: 2900, Frontier size: 1638
# Nodes explored: 3000, Frontier size: 1672
# Nodes explored: 3100, Frontier size: 1713
# Nodes explored: 3200, Frontier size: 1747
# Nodes explored: 3300, Frontier size: 1779
# Nodes explored: 3400, Frontier size: 1829
# Nodes explored: 3500, Frontier size: 1913
# Nodes explored: 3600, Frontier size: 1992
# Nodes explored: 3700, Frontier size: 2075
# Nodes explored: 3800, Frontier size: 2160
# Nodes explored: 3900, Frontier size: 2246
# Nodes explored: 4000, Frontier size: 2325
# Nodes explored: 4100, Frontier size: 2407
# Nodes explored: 4200, Frontier size: 2494
# Nodes explored: 4300, Frontier size: 2572
# Nodes explored: 4400, Frontier size: 2652
# Nodes explored: 4500, Frontier size: 2737
# Nodes explored: 4600, Frontier size: 2816
# Nodes explored: 4700, Frontier size: 2901
# Nodes explored: 4800, Frontier size: 2980
# Nodes explored: 4900, Frontier size: 3059
# Nodes explored: 5000, Frontier size: 3140
# Nodes explored: 5100, Frontier size: 3223
# Nodes explored: 5200, Frontier size: 3290
# Nodes explored: 5300, Frontier size: 3320
# Nodes explored: 5400, Frontier size: 3351
# Nodes explored: 5500, Frontier size: 3387
# Nodes explored: 5600, Frontier size: 3418
# Nodes explored: 5700, Frontier size: 3450
# Nodes explored: 5800, Frontier size: 3480
# Nodes explored: 5900, Frontier size: 3507
# Nodes explored: 6000, Frontier size: 3540
# Nodes explored: 6100, Frontier size: 3563
# Nodes explored: 6200, Frontier size: 3597
# Nodes explored: 6300, Frontier size: 3620
# Nodes explored: 6400, Frontier size: 3655
# Nodes explored: 6500, Frontier size: 3675
# Nodes explored: 6600, Frontier size: 3700
# Nodes explored: 6700, Frontier size: 3724
# Nodes explored: 6800, Frontier size: 3752
# Nodes explored: 6900, Frontier size: 3779
# Nodes explored: 7000, Frontier size: 3800
# Nodes explored: 7100, Frontier size: 3836
# Nodes explored: 7200, Frontier size: 3860
# Nodes explored: 7300, Frontier size: 3895
# Nodes explored: 7400, Frontier size: 3920
# Nodes explored: 7500, Frontier size: 3947
# Nodes explored: 7600, Frontier size: 3978
# Nodes explored: 7700, Frontier size: 4003
# Nodes explored: 7800, Frontier size: 4021
# Nodes explored: 7900, Frontier size: 4054
# Nodes explored: 8000, Frontier size: 4081
# Nodes explored: 8100, Frontier size: 4110
# Nodes explored: 8200, Frontier size: 4129
# Nodes explored: 8300, Frontier size: 4156
# Nodes explored: 8400, Frontier size: 4183
# Nodes explored: 8500, Frontier size: 4227
# Nodes explored: 8600, Frontier size: 4300
# Nodes explored: 8700, Frontier size: 4379
# Nodes explored: 8800, Frontier size: 4456
# Nodes explored: 8900, Frontier size: 4535
# Nodes explored: 9000, Frontier size: 4608
# Nodes explored: 9100, Frontier size: 4686
# Nodes explored: 9200, Frontier size: 4764
# Nodes explored: 9300, Frontier size: 4839
# Nodes explored: 9400, Frontier size: 4918
# Nodes explored: 9500, Frontier size: 4996
# Nodes explored: 9600, Frontier size: 5072
# Nodes explored: 9700, Frontier size: 5149
# Nodes explored: 9800, Frontier size: 5230
# Nodes explored: 9900, Frontier size: 5304
# Nodes explored: 10000, Frontier size: 5382
# Nodes explored: 10100, Frontier size: 5453
# Nodes explored: 10200, Frontier size: 5529
# Nodes explored: 10300, Frontier size: 5602
# Nodes explored: 10400, Frontier size: 5680
# Nodes explored: 10500, Frontier size: 5750
# Nodes explored: 10600, Frontier size: 5827
# Nodes explored: 10700, Frontier size: 5904
# Nodes explored: 10800, Frontier size: 5979
# Nodes explored: 10900, Frontier size: 6057
# Nodes explored: 11000, Frontier size: 6126
# Nodes explored: 11100, Frontier size: 6199
# Nodes explored: 11200, Frontier size: 6274
# Nodes explored: 11300, Frontier size: 6350
# Nodes explored: 11400, Frontier size: 6417
# Nodes explored: 11500, Frontier size: 6491
# Nodes explored: 11600, Frontier size: 6564
# Nodes explored: 11700, Frontier size: 6636
# Nodes explored: 11800, Frontier size: 6713
# Nodes explored: 11900, Frontier size: 6784
# Nodes explored: 12000, Frontier size: 6859
# Nodes explored: 12100, Frontier size: 6937
# Nodes explored: 12200, Frontier size: 7008
# Nodes explored: 12300, Frontier size: 7074
# Nodes explored: 12400, Frontier size: 7138
# Nodes explored: 12500, Frontier size: 7211
# Nodes explored: 12600, Frontier size: 7287
# Nodes explored: 12700, Frontier size: 7338
# Nodes explored: 12800, Frontier size: 7362
# Nodes explored: 12900, Frontier size: 7389
# Nodes explored: 13000, Frontier size: 7412
# Nodes explored: 13100, Frontier size: 7440
# Nodes explored: 13200, Frontier size: 7477
# Nodes explored: 13300, Frontier size: 7501
# Nodes explored: 13400, Frontier size: 7524
# Nodes explored: 13500, Frontier size: 7543
# Nodes explored: 13600, Frontier size: 7568
# Nodes explored: 13700, Frontier size: 7593
# Nodes explored: 13800, Frontier size: 7618
# Nodes explored: 13900, Frontier size: 7650
# Nodes explored: 14000, Frontier size: 7672
# Nodes explored: 14100, Frontier size: 7687
# Nodes explored: 14200, Frontier size: 7715
# Nodes explored: 14300, Frontier size: 7734
# Nodes explored: 14400, Frontier size: 7765
# Nodes explored: 14500, Frontier size: 7785
# Nodes explored: 14600, Frontier size: 7798
# Nodes explored: 14700, Frontier size: 7813
# Nodes explored: 14800, Frontier size: 7842
# Nodes explored: 14900, Frontier size: 7863
# Nodes explored: 15000, Frontier size: 7891
# Nodes explored: 15100, Frontier size: 7906
# Nodes explored: 15200, Frontier size: 7921
# Nodes explored: 15300, Frontier size: 7930
# Nodes explored: 15400, Frontier size: 7949
# Nodes explored: 15500, Frontier size: 7974
# Nodes explored: 15600, Frontier size: 7997
# Nodes explored: 15700, Frontier size: 8016
# Nodes explored: 15800, Frontier size: 8033
# Nodes explored: 15900, Frontier size: 8044
# Nodes explored: 16000, Frontier size: 8066
# Nodes explored: 16100, Frontier size: 8085
# Nodes explored: 16200, Frontier size: 8109
# Nodes explored: 16300, Frontier size: 8125
# Nodes explored: 16400, Frontier size: 8139
# Nodes explored: 16500, Frontier size: 8144
# Nodes explored: 16600, Frontier size: 8159
# Nodes explored: 16700, Frontier size: 8179
# Nodes explored: 16800, Frontier size: 8204
# Nodes explored: 16900, Frontier size: 8225
# Nodes explored: 17000, Frontier size: 8239
# Nodes explored: 17100, Frontier size: 8246
# Nodes explored: 17200, Frontier size: 8273
# Nodes explored: 17300, Frontier size: 8289
# Nodes explored: 17400, Frontier size: 8306
# Nodes explored: 17500, Frontier size: 8327
# Nodes explored: 17600, Frontier size: 8338
# Nodes explored: 17700, Frontier size: 8350
# Nodes explored: 17800, Frontier size: 8380
# Nodes explored: 17900, Frontier size: 8396
# Nodes explored: 18000, Frontier size: 8404
# Nodes explored: 18100, Frontier size: 8412
# Nodes explored: 18200, Frontier size: 8422
# Nodes explored: 18300, Frontier size: 8444
# Nodes explored: 18400, Frontier size: 8452
# Nodes explored: 18500, Frontier size: 8464
# Nodes explored: 18600, Frontier size: 8476
# Nodes explored: 18700, Frontier size: 8477
# Nodes explored: 18800, Frontier size: 8482
# Nodes explored: 18900, Frontier size: 8487
# Nodes explored: 19000, Frontier size: 8495
# Nodes explored: 19100, Frontier size: 8504
# Nodes explored: 19200, Frontier size: 8523
# Nodes explored: 19300, Frontier size: 8539
# Nodes explored: 19400, Frontier size: 8552
# Nodes explored: 19500, Frontier size: 8555
# Nodes explored: 19600, Frontier size: 8572
# Nodes explored: 19700, Frontier size: 8576
# Nodes explored: 19800, Frontier size: 8578
# Nodes explored: 19900, Frontier size: 8582
# Nodes explored: 20000, Frontier size: 8613
# Nodes explored: 20100, Frontier size: 8686
# Nodes explored: 20200, Frontier size: 8752
# Nodes explored: 20300, Frontier size: 8812
# Nodes explored: 20400, Frontier size: 8876
# Nodes explored: 20500, Frontier size: 8937
# Nodes explored: 20600, Frontier size: 9008
# Nodes explored: 20700, Frontier size: 9081
# Nodes explored: 20800, Frontier size: 9143
# Nodes explored: 20900, Frontier size: 9213
# Nodes explored: 21000, Frontier size: 9284
# Nodes explored: 21100, Frontier size: 9354
# Nodes explored: 21200, Frontier size: 9418
# Nodes explored: 21300, Frontier size: 9481
# Nodes explored: 21400, Frontier size: 9543
# Nodes explored: 21500, Frontier size: 9607
# Nodes explored: 21600, Frontier size: 9677
# Nodes explored: 21700, Frontier size: 9738
# Nodes explored: 21800, Frontier size: 9795
# Nodes explored: 21900, Frontier size: 9858
# Nodes explored: 22000, Frontier size: 9930
# Nodes explored: 22100, Frontier size: 10000
# Nodes explored: 22200, Frontier size: 10064
# Nodes explored: 22300, Frontier size: 10125
# Nodes explored: 22400, Frontier size: 10179
# Nodes explored: 22500, Frontier size: 10238
# Nodes explored: 22600, Frontier size: 10291
# Nodes explored: 22700, Frontier size: 10357
# Nodes explored: 22800, Frontier size: 10429
# Nodes explored: 22900, Frontier size: 10493
# Nodes explored: 23000, Frontier size: 10558
# Nodes explored: 23100, Frontier size: 10619
# Nodes explored: 23200, Frontier size: 10679
# Nodes explored: 23300, Frontier size: 10741
# Nodes explored: 23400, Frontier size: 10799
# Nodes explored: 23500, Frontier size: 10854
# Nodes explored: 23600, Frontier size: 10918
# Nodes explored: 23700, Frontier size: 10982
# Nodes explored: 23800, Frontier size: 11031
# Nodes explored: 23900, Frontier size: 11082
# Nodes explored: 24000, Frontier size: 11134
# Nodes explored: 24100, Frontier size: 11194
# Nodes explored: 24200, Frontier size: 11246
# Nodes explored: 24300, Frontier size: 11308
# Nodes explored: 24400, Frontier size: 11372
# Nodes explored: 24500, Frontier size: 11427
# Nodes explored: 24600, Frontier size: 11481
# Nodes explored: 24700, Frontier size: 11540
# Nodes explored: 24800, Frontier size: 11596
# Nodes explored: 24900, Frontier size: 11664
# Nodes explored: 25000, Frontier size: 11730
# Nodes explored: 25100, Frontier size: 11793
# Nodes explored: 25200, Frontier size: 11862
# Nodes explored: 25300, Frontier size: 11925
# Nodes explored: 25400, Frontier size: 11978
# Nodes explored: 25500, Frontier size: 12033
# Nodes explored: 25600, Frontier size: 12080
# Nodes explored: 25700, Frontier size: 12140
# Nodes explored: 25800, Frontier size: 12208
# Nodes explored: 25900, Frontier size: 12264
# Nodes explored: 26000, Frontier size: 12314
# Nodes explored: 26100, Frontier size: 12370
# Nodes explored: 26200, Frontier size: 12435
# Nodes explored: 26300, Frontier size: 12493
# Nodes explored: 26400, Frontier size: 12557
# Nodes explored: 26500, Frontier size: 12623
# Nodes explored: 26600, Frontier size: 12691
# Nodes explored: 26700, Frontier size: 12745
# Nodes explored: 26800, Frontier size: 12814
# Nodes explored: 26900, Frontier size: 12879
# Nodes explored: 27000, Frontier size: 12946
# Nodes explored: 27100, Frontier size: 13011
# Nodes explored: 27200, Frontier size: 13077
# Nodes explored: 27300, Frontier size: 13140
# Nodes explored: 27400, Frontier size: 13204
# Nodes explored: 27500, Frontier size: 13258
# Nodes explored: 27600, Frontier size: 13319
# Nodes explored: 27700, Frontier size: 13388
# Nodes explored: 27800, Frontier size: 13452
# Nodes explored: 27900, Frontier size: 13507
# Nodes explored: 28000, Frontier size: 13563
# Nodes explored: 28100, Frontier size: 13616
# Nodes explored: 28200, Frontier size: 13684
# Nodes explored: 28300, Frontier size: 13750
# Nodes explored: 28400, Frontier size: 13818
# Nodes explored: 28500, Frontier size: 13879
# Nodes explored: 28600, Frontier size: 13932
# Nodes explored: 28700, Frontier size: 13950
# Nodes explored: 28800, Frontier size: 13980
# Nodes explored: 28900, Frontier size: 14002
# Nodes explored: 29000, Frontier size: 14007
# Nodes explored: 29100, Frontier size: 14016
# Nodes explored: 29200, Frontier size: 14031
# Nodes explored: 29300, Frontier size: 14034
# Nodes explored: 29400, Frontier size: 14056
# Nodes explored: 29500, Frontier size: 14074
# Nodes explored: 29600, Frontier size: 14083
# Nodes explored: 29700, Frontier size: 14099
# Nodes explored: 29800, Frontier size: 14108
# Nodes explored: 29900, Frontier size: 14130
# Nodes explored: 30000, Frontier size: 14131
# Nodes explored: 30100, Frontier size: 14136
# Nodes explored: 30200, Frontier size: 14143
# Nodes explored: 30300, Frontier size: 14162
# Nodes explored: 30400, Frontier size: 14171
# Nodes explored: 30500, Frontier size: 14170
# Nodes explored: 30600, Frontier size: 14169
# Nodes explored: 30700, Frontier size: 14171
# Nodes explored: 30800, Frontier size: 14188
# Nodes explored: 30900, Frontier size: 14182
# Nodes explored: 31000, Frontier size: 14193
# Nodes explored: 31100, Frontier size: 14212
# Nodes explored: 31200, Frontier size: 14215
# Nodes explored: 31300, Frontier size: 14228
# Nodes explored: 31400, Frontier size: 14227
# Nodes explored: 31500, Frontier size: 14239
# Nodes explored: 31600, Frontier size: 14242
# Nodes explored: 31700, Frontier size: 14266
# Nodes explored: 31800, Frontier size: 14280
# Nodes explored: 31900, Frontier size: 14290
# Nodes explored: 32000, Frontier size: 14295
# Nodes explored: 32100, Frontier size: 14308
# Nodes explored: 32200, Frontier size: 14317
# Nodes explored: 32300, Frontier size: 14333
# Nodes explored: 32400, Frontier size: 14330
# Nodes explored: 32500, Frontier size: 14340
# Nodes explored: 32600, Frontier size: 14358
# Nodes explored: 32700, Frontier size: 14370
# Nodes explored: 32800, Frontier size: 14376
# Nodes explored: 32900, Frontier size: 14386
# Nodes explored: 33000, Frontier size: 14394
# Nodes explored: 33100, Frontier size: 14404
# Nodes explored: 33200, Frontier size: 14413
# Nodes explored: 33300, Frontier size: 14416
# Nodes explored: 33400, Frontier size: 14420
# Nodes explored: 33500, Frontier size: 14432
# Nodes explored: 33600, Frontier size: 14436
# Nodes explored: 33700, Frontier size: 14425
# Nodes explored: 33800, Frontier size: 14425
# Nodes explored: 33900, Frontier size: 14433
# Nodes explored: 34000, Frontier size: 14435
# Nodes explored: 34100, Frontier size: 14431
# Nodes explored: 34200, Frontier size: 14451
# Nodes explored: 34300, Frontier size: 14451
# Nodes explored: 34400, Frontier size: 14464
# Nodes explored: 34500, Frontier size: 14472
# Nodes explored: 34600, Frontier size: 14486
# Nodes explored: 34700, Frontier size: 14495
# Nodes explored: 34800, Frontier size: 14502
# Nodes explored: 34900, Frontier size: 14501
# Nodes explored: 35000, Frontier size: 14517
# Nodes explored: 35100, Frontier size: 14532
# Nodes explored: 35200, Frontier size: 14540
# Nodes explored: 35300, Frontier size: 14542
# Nodes explored: 35400, Frontier size: 14543
# Nodes explored: 35500, Frontier size: 14548
# Nodes explored: 35600, Frontier size: 14564
# Nodes explored: 35700, Frontier size: 14567
# Nodes explored: 35800, Frontier size: 14579
# Nodes explored: 35900, Frontier size: 14575
# Nodes explored: 36000, Frontier size: 14571
# Nodes explored: 36100, Frontier size: 14571
# Nodes explored: 36200, Frontier size: 14580
# Nodes explored: 36300, Frontier size: 14573
# Nodes explored: 36400, Frontier size: 14582
# Nodes explored: 36500, Frontier size: 14594
# Nodes explored: 36600, Frontier size: 14601
# Nodes explored: 36700, Frontier size: 14613
# Nodes explored: 36800, Frontier size: 14622
# Nodes explored: 36900, Frontier size: 14617
# Nodes explored: 37000, Frontier size: 14622
# Nodes explored: 37100, Frontier size: 14626
# Nodes explored: 37200, Frontier size: 14632
# Nodes explored: 37300, Frontier size: 14627
# Nodes explored: 37400, Frontier size: 14636
# Nodes explored: 37500, Frontier size: 14638
# Nodes explored: 37600, Frontier size: 14647
# Nodes explored: 37700, Frontier size: 14642
# Nodes explored: 37800, Frontier size: 14646
# Nodes explored: 37900, Frontier size: 14658
# Nodes explored: 38000, Frontier size: 14668
# Nodes explored: 38100, Frontier size: 14663
# Nodes explored: 38200, Frontier size: 14664
# Nodes explored: 38300, Frontier size: 14657
# Nodes explored: 38400, Frontier size: 14677
# Nodes explored: 38500, Frontier size: 14667
# Nodes explored: 38600, Frontier size: 14667
# Nodes explored: 38700, Frontier size: 14672
# Nodes explored: 38800, Frontier size: 14677
# Nodes explored: 38900, Frontier size: 14682
# Nodes explored: 39000, Frontier size: 14694
# Nodes explored: 39100, Frontier size: 14697
# Nodes explored: 39200, Frontier size: 14696
# Nodes explored: 39300, Frontier size: 14705
# Nodes explored: 39400, Frontier size: 14703
# Nodes explored: 39500, Frontier size: 14701
# Nodes explored: 39600, Frontier size: 14708
# Nodes explored: 39700, Frontier size: 14702
# Nodes explored: 39800, Frontier size: 14723
# Nodes explored: 39900, Frontier size: 14725
# Nodes explored: 40000, Frontier size: 14728
# Nodes explored: 40100, Frontier size: 14736
# Nodes explored: 40200, Frontier size: 14738
# Nodes explored: 40300, Frontier size: 14732
# Nodes explored: 40400, Frontier size: 14727
# Nodes explored: 40500, Frontier size: 14724
# Nodes explored: 40600, Frontier size: 14733
# Nodes explored: 40700, Frontier size: 14734
# Nodes explored: 40800, Frontier size: 14732
# Nodes explored: 40900, Frontier size: 14727
# Nodes explored: 41000, Frontier size: 14732
# Nodes explored: 41100, Frontier size: 14729
# Nodes explored: 41200, Frontier size: 14728
# Nodes explored: 41300, Frontier size: 14722
# Nodes explored: 41400, Frontier size: 14732
# Nodes explored: 41500, Frontier size: 14739
# Nodes explored: 41600, Frontier size: 14729
# Nodes explored: 41700, Frontier size: 14739
# Nodes explored: 41800, Frontier size: 14731
# Nodes explored: 41900, Frontier size: 14728
# Nodes explored: 42000, Frontier size: 14727
# Nodes explored: 42100, Frontier size: 14719
# Nodes explored: 42200, Frontier size: 14717
# Nodes explored: 42300, Frontier size: 14729
# Nodes explored: 42400, Frontier size: 14710
# Nodes explored: 42500, Frontier size: 14714
# Nodes explored: 42600, Frontier size: 14770
# Nodes explored: 42700, Frontier size: 14819
# Nodes explored: 42800, Frontier size: 14871
# Nodes explored: 42900, Frontier size: 14924
# Nodes explored: 43000, Frontier size: 14978
# Nodes explored: 43100, Frontier size: 15020
# Nodes explored: 43200, Frontier size: 15073
# Nodes explored: 43300, Frontier size: 15106
# Nodes explored: 43400, Frontier size: 15157
# Nodes explored: 43500, Frontier size: 15209
# Nodes explored: 43600, Frontier size: 15260
# Nodes explored: 43700, Frontier size: 15307
# Nodes explored: 43800, Frontier size: 15366
# Nodes explored: 43900, Frontier size: 15416
# Nodes explored: 44000, Frontier size: 15471
# Nodes explored: 44100, Frontier size: 15528
# Nodes explored: 44200, Frontier size: 15586
# Nodes explored: 44300, Frontier size: 15646
# Nodes explored: 44400, Frontier size: 15702
# Nodes explored: 44500, Frontier size: 15758
# Nodes explored: 44600, Frontier size: 15815
# Nodes explored: 44700, Frontier size: 15872
# Nodes explored: 44800, Frontier size: 15925
# Nodes explored: 44900, Frontier size: 15973
# Nodes explored: 45000, Frontier size: 16019
# Nodes explored: 45100, Frontier size: 16069
# Nodes explored: 45200, Frontier size: 16125
# Nodes explored: 45300, Frontier size: 16180
# Nodes explored: 45400, Frontier size: 16233
# Nodes explored: 45500, Frontier size: 16293
# Nodes explored: 45600, Frontier size: 16352
# Nodes explored: 45700, Frontier size: 16412
# Nodes explored: 45800, Frontier size: 16454
# Nodes explored: 45900, Frontier size: 16511
# Nodes explored: 46000, Frontier size: 16545
# Nodes explored: 46100, Frontier size: 16602
# Nodes explored: 46200, Frontier size: 16642
# Nodes explored: 46300, Frontier size: 16689
# Nodes explored: 46400, Frontier size: 16735
# Nodes explored: 46500, Frontier size: 16782
# Nodes explored: 46600, Frontier size: 16832
# Nodes explored: 46700, Frontier size: 16887
# Nodes explored: 46800, Frontier size: 16936
# Nodes explored: 46900, Frontier size: 16972
# Nodes explored: 47000, Frontier size: 17007
# Nodes explored: 47100, Frontier size: 17056
# Nodes explored: 47200, Frontier size: 17102
# Nodes explored: 47300, Frontier size: 17157
# Nodes explored: 47400, Frontier size: 17213
# Nodes explored: 47500, Frontier size: 17261
# Nodes explored: 47600, Frontier size: 17311
# Nodes explored: 47700, Frontier size: 17354
# Nodes explored: 47800, Frontier size: 17406
# Nodes explored: 47900, Frontier size: 17462
# Nodes explored: 48000, Frontier size: 17515
# Nodes explored: 48100, Frontier size: 17558
# Nodes explored: 48200, Frontier size: 17609
# Nodes explored: 48300, Frontier size: 17648
# Nodes explored: 48400, Frontier size: 17691
# Nodes explored: 48500, Frontier size: 17743
# Nodes explored: 48600, Frontier size: 17782
# Nodes explored: 48700, Frontier size: 17822
# Nodes explored: 48800, Frontier size: 17871
# Nodes explored: 48900, Frontier size: 17915
# Nodes explored: 49000, Frontier size: 17956
# Nodes explored: 49100, Frontier size: 18008
# Nodes explored: 49200, Frontier size: 18052
# Nodes explored: 49300, Frontier size: 18086
# Nodes explored: 49400, Frontier size: 18130
# Nodes explored: 49500, Frontier size: 18157
# Nodes explored: 49600, Frontier size: 18195
# Nodes explored: 49700, Frontier size: 18239
# Nodes explored: 49800, Frontier size: 18277
# Nodes explored: 49900, Frontier size: 18320
# Nodes explored: 50000, Frontier size: 18373
# Nodes explored: 50100, Frontier size: 18423
# Nodes explored: 50200, Frontier size: 18465
# Nodes explored: 50300, Frontier size: 18512
# Nodes explored: 50400, Frontier size: 18554
# Nodes explored: 50500, Frontier size: 18587
# Nodes explored: 50600, Frontier size: 18630
# Nodes explored: 50700, Frontier size: 18669
# Nodes explored: 50800, Frontier size: 18707
# Nodes explored: 50900, Frontier size: 18758
# Nodes explored: 51000, Frontier size: 18814
# Nodes explored: 51100, Frontier size: 18877
# Nodes explored: 51200, Frontier size: 18921
# Nodes explored: 51300, Frontier size: 18961
# Nodes explored: 51400, Frontier size: 19011
# Nodes explored: 51500, Frontier size: 19060
# Nodes explored: 51600, Frontier size: 19117
# Nodes explored: 51700, Frontier size: 19176
# Nodes explored: 51800, Frontier size: 19236
# Nodes explored: 51900, Frontier size: 19275
# Nodes explored: 52000, Frontier size: 19310
# Nodes explored: 52100, Frontier size: 19346
# Nodes explored: 52200, Frontier size: 19406
# Nodes explored: 52300, Frontier size: 19461
# Nodes explored: 52400, Frontier size: 19508
# Nodes explored: 52500, Frontier size: 19551
# Nodes explored: 52600, Frontier size: 19608
# Nodes explored: 52700, Frontier size: 19651
# Nodes explored: 52800, Frontier size: 19700
# Nodes explored: 52900, Frontier size: 19747
# Nodes explored: 53000, Frontier size: 19792
# Nodes explored: 53100, Frontier size: 19840
# Nodes explored: 53200, Frontier size: 19890
# Nodes explored: 53300, Frontier size: 19939
# Nodes explored: 53400, Frontier size: 19992
# Nodes explored: 53500, Frontier size: 20027
# Nodes explored: 53600, Frontier size: 20077
# Nodes explored: 53700, Frontier size: 20122
# Nodes explored: 53800, Frontier size: 20173
# Nodes explored: 53900, Frontier size: 20223
# Nodes explored: 54000, Frontier size: 20268
# Nodes explored: 54100, Frontier size: 20304
# Nodes explored: 54200, Frontier size: 20354
# Nodes explored: 54300, Frontier size: 20411
# Nodes explored: 54400, Frontier size: 20445
# Nodes explored: 54500, Frontier size: 20496
# Nodes explored: 54600, Frontier size: 20538
# Nodes explored: 54700, Frontier size: 20590
# Nodes explored: 54800, Frontier size: 20649
# Nodes explored: 54900, Frontier size: 20701
# Nodes explored: 55000, Frontier size: 20745
# Nodes explored: 55100, Frontier size: 20785
# Nodes explored: 55200, Frontier size: 20824
# Nodes explored: 55300, Frontier size: 20860
# Nodes explored: 55400, Frontier size: 20911
# Nodes explored: 55500, Frontier size: 20952
# Nodes explored: 55600, Frontier size: 20992
# Nodes explored: 55700, Frontier size: 21034
# Nodes explored: 55800, Frontier size: 21073
# Nodes explored: 55900, Frontier size: 21124
# Nodes explored: 56000, Frontier size: 21175
# Nodes explored: 56100, Frontier size: 21221
# Nodes explored: 56200, Frontier size: 21261
# Nodes explored: 56300, Frontier size: 21310
# Nodes explored: 56400, Frontier size: 21353
# Nodes explored: 56500, Frontier size: 21405
# Nodes explored: 56600, Frontier size: 21457
# Nodes explored: 56700, Frontier size: 21503
# Nodes explored: 56800, Frontier size: 21540
# Nodes explored: 56900, Frontier size: 21585
# Nodes explored: 57000, Frontier size: 21626
# Nodes explored: 57100, Frontier size: 21663
# Nodes explored: 57200, Frontier size: 21713
# Nodes explored: 57300, Frontier size: 21729
# Nodes explored: 57400, Frontier size: 21748
# Nodes explored: 57500, Frontier size: 21742
# Nodes explored: 57600, Frontier size: 21752
# Nodes explored: 57700, Frontier size: 21754
# Nodes explored: 57800, Frontier size: 21753
# Nodes explored: 57900, Frontier size: 21765
# Nodes explored: 58000, Frontier size: 21756
# Nodes explored: 58100, Frontier size: 21761
# Nodes explored: 58200, Frontier size: 21760
# Nodes explored: 58300, Frontier size: 21769
# Nodes explored: 58400, Frontier size: 21762
# Nodes explored: 58500, Frontier size: 21765
# Nodes explored: 58600, Frontier size: 21780
# Nodes explored: 58700, Frontier size: 21773
# Nodes explored: 58800, Frontier size: 21780
# Nodes explored: 58900, Frontier size: 21775
# Nodes explored: 59000, Frontier size: 21772
# Nodes explored: 59100, Frontier size: 21777
# Nodes explored: 59200, Frontier size: 21772
# Nodes explored: 59300, Frontier size: 21767
# Nodes explored: 59400, Frontier size: 21769
# Nodes explored: 59500, Frontier size: 21767
# Nodes explored: 59600, Frontier size: 21785
# Nodes explored: 59700, Frontier size: 21786
# Nodes explored: 59800, Frontier size: 21792
# Nodes explored: 59900, Frontier size: 21786
# Nodes explored: 60000, Frontier size: 21801
# Nodes explored: 60100, Frontier size: 21806
# Nodes explored: 60200, Frontier size: 21819
# Nodes explored: 60300, Frontier size: 21819
# Nodes explored: 60400, Frontier size: 21815
# Nodes explored: 60500, Frontier size: 21805
# Nodes explored: 60600, Frontier size: 21802
# Nodes explored: 60700, Frontier size: 21806
# Nodes explored: 60800, Frontier size: 21805
# Nodes explored: 60900, Frontier size: 21794
# Nodes explored: 61000, Frontier size: 21793
# Nodes explored: 61100, Frontier size: 21798
# Nodes explored: 61200, Frontier size: 21803
# Nodes explored: 61300, Frontier size: 21792
# Nodes explored: 61400, Frontier size: 21790
# Nodes explored: 61500, Frontier size: 21780
# Nodes explored: 61600, Frontier size: 21782
# Nodes explored: 61700, Frontier size: 21764
# Nodes explored: 61800, Frontier size: 21760
# Nodes explored: 61900, Frontier size: 21768
# Nodes explored: 62000, Frontier size: 21775
# Nodes explored: 62100, Frontier size: 21771
# Nodes explored: 62200, Frontier size: 21779
# Nodes explored: 62300, Frontier size: 21779
# Nodes explored: 62400, Frontier size: 21798
# Nodes explored: 62500, Frontier size: 21792
# Nodes explored: 62600, Frontier size: 21803
# Nodes explored: 62700, Frontier size: 21812
# Nodes explored: 62800, Frontier size: 21811
# Nodes explored: 62900, Frontier size: 21799
# Nodes explored: 63000, Frontier size: 21803
# Nodes explored: 63100, Frontier size: 21808
# Nodes explored: 63200, Frontier size: 21789
# Nodes explored: 63300, Frontier size: 21790
# Nodes explored: 63400, Frontier size: 21789
# Nodes explored: 63500, Frontier size: 21778
# Nodes explored: 63600, Frontier size: 21768
# Nodes explored: 63700, Frontier size: 21758
# Nodes explored: 63800, Frontier size: 21741
# Nodes explored: 63900, Frontier size: 21725
# Nodes explored: 64000, Frontier size: 21717
# Nodes explored: 64100, Frontier size: 21706
# Nodes explored: 64200, Frontier size: 21709
# Nodes explored: 64300, Frontier size: 21710
# Nodes explored: 64400, Frontier size: 21704
# Nodes explored: 64500, Frontier size: 21716
# Nodes explored: 64600, Frontier size: 21719
# Nodes explored: 64700, Frontier size: 21710
# Nodes explored: 64800, Frontier size: 21704
# Nodes explored: 64900, Frontier size: 21702
# Nodes explored: 65000, Frontier size: 21695
# Nodes explored: 65100, Frontier size: 21694
# Nodes explored: 65200, Frontier size: 21685
# Nodes explored: 65300, Frontier size: 21676
# Nodes explored: 65400, Frontier size: 21676
# Nodes explored: 65500, Frontier size: 21676
# Nodes explored: 65600, Frontier size: 21663
# Nodes explored: 65700, Frontier size: 21659
# Nodes explored: 65800, Frontier size: 21642
# Nodes explored: 65900, Frontier size: 21632
# Nodes explored: 66000, Frontier size: 21613
# Nodes explored: 66100, Frontier size: 21606
# Nodes explored: 66200, Frontier size: 21598
# Nodes explored: 66300, Frontier size: 21599
# Nodes explored: 66400, Frontier size: 21601
# Nodes explored: 66500, Frontier size: 21600
# Nodes explored: 66600, Frontier size: 21610
# Nodes explored: 66700, Frontier size: 21619
# Nodes explored: 66800, Frontier size: 21619
# Nodes explored: 66900, Frontier size: 21612
# Nodes explored: 67000, Frontier size: 21604
# Nodes explored: 67100, Frontier size: 21595
# Nodes explored: 67200, Frontier size: 21597
# Nodes explored: 67300, Frontier size: 21586
# Nodes explored: 67400, Frontier size: 21572
# Nodes explored: 67500, Frontier size: 21564
# Nodes explored: 67600, Frontier size: 21554
# Nodes explored: 67700, Frontier size: 21537
# Nodes explored: 67800, Frontier size: 21532
# Nodes explored: 67900, Frontier size: 21533
# Nodes explored: 68000, Frontier size: 21526
# Nodes explored: 68100, Frontier size: 21530
# Nodes explored: 68200, Frontier size: 21522
# Nodes explored: 68300, Frontier size: 21519
# Nodes explored: 68400, Frontier size: 21520
# Nodes explored: 68500, Frontier size: 21510
# Nodes explored: 68600, Frontier size: 21511
# Nodes explored: 68700, Frontier size: 21511
# Nodes explored: 68800, Frontier size: 21492
# Nodes explored: 68900, Frontier size: 21486
# Nodes explored: 69000, Frontier size: 21474
# Nodes explored: 69100, Frontier size: 21458
# Nodes explored: 69200, Frontier size: 21454
# Nodes explored: 69300, Frontier size: 21432
# Nodes explored: 69400, Frontier size: 21426
# Nodes explored: 69500, Frontier size: 21414
# Nodes explored: 69600, Frontier size: 21413
# Nodes explored: 69700, Frontier size: 21413
# Nodes explored: 69800, Frontier size: 21409
# Nodes explored: 69900, Frontier size: 21418
# Nodes explored: 70000, Frontier size: 21410
# Nodes explored: 70100, Frontier size: 21404
# Nodes explored: 70200, Frontier size: 21396
# Nodes explored: 70300, Frontier size: 21377
# Nodes explored: 70400, Frontier size: 21369
# Nodes explored: 70500, Frontier size: 21351
# Nodes explored: 70600, Frontier size: 21342
# Nodes explored: 70700, Frontier size: 21336
# Nodes explored: 70800, Frontier size: 21340
# Nodes explored: 70900, Frontier size: 21333
# Nodes explored: 71000, Frontier size: 21321
# Nodes explored: 71100, Frontier size: 21311
# Nodes explored: 71200, Frontier size: 21286
# Nodes explored: 71300, Frontier size: 21263
# Nodes explored: 71400, Frontier size: 21257
# Nodes explored: 71500, Frontier size: 21231
# Nodes explored: 71600, Frontier size: 21215
# Nodes explored: 71700, Frontier size: 21193
# Nodes explored: 71800, Frontier size: 21165
# Nodes explored: 71900, Frontier size: 21152
# Nodes explored: 72000, Frontier size: 21141
# Nodes explored: 72100, Frontier size: 21121
# Nodes explored: 72200, Frontier size: 21110
# Nodes explored: 72300, Frontier size: 21093
# Nodes explored: 72400, Frontier size: 21080
# Nodes explored: 72500, Frontier size: 21066
# Nodes explored: 72600, Frontier size: 21051
# Nodes explored: 72700, Frontier size: 21047
# Nodes explored: 72800, Frontier size: 21031
# Nodes explored: 72900, Frontier size: 21014
# Nodes explored: 73000, Frontier size: 21003
# Nodes explored: 73100, Frontier size: 20988
# Nodes explored: 73200, Frontier size: 20977
# Nodes explored: 73300, Frontier size: 20953
# Nodes explored: 73400, Frontier size: 20925
# Nodes explored: 73500, Frontier size: 20893
# Nodes explored: 73600, Frontier size: 20880
# Nodes explored: 73700, Frontier size: 20863
# Nodes explored: 73800, Frontier size: 20854
# Nodes explored: 73900, Frontier size: 20834
# Nodes explored: 74000, Frontier size: 20811
# Nodes explored: 74100, Frontier size: 20792
# Nodes explored: 74200, Frontier size: 20776
# Nodes explored: 74300, Frontier size: 20753
# Nodes explored: 74400, Frontier size: 20732
# Nodes explored: 74500, Frontier size: 20709
# Nodes explored: 74600, Frontier size: 20699
# Nodes explored: 74700, Frontier size: 20688
# Nodes explored: 74800, Frontier size: 20685
# Nodes explored: 74900, Frontier size: 20656
# Nodes explored: 75000, Frontier size: 20657
# Nodes explored: 75100, Frontier size: 20660
# Nodes explored: 75200, Frontier size: 20626
# Nodes explored: 75300, Frontier size: 20619
# Nodes explored: 75400, Frontier size: 20608
# Nodes explored: 75500, Frontier size: 20602
# Nodes explored: 75600, Frontier size: 20577
# Nodes explored: 75700, Frontier size: 20549
# Nodes explored: 75800, Frontier size: 20523
# Nodes explored: 75900, Frontier size: 20509
# Nodes explored: 76000, Frontier size: 20484
# Nodes explored: 76100, Frontier size: 20458
# Nodes explored: 76200, Frontier size: 20442
# Nodes explored: 76300, Frontier size: 20423
# Nodes explored: 76400, Frontier size: 20391
# Nodes explored: 76500, Frontier size: 20370
# Nodes explored: 76600, Frontier size: 20343
# Nodes explored: 76700, Frontier size: 20320
# Nodes explored: 76800, Frontier size: 20305
# Nodes explored: 76900, Frontier size: 20279
# Nodes explored: 77000, Frontier size: 20259
# Nodes explored: 77100, Frontier size: 20243
# Nodes explored: 77200, Frontier size: 20228
# Nodes explored: 77300, Frontier size: 20203
# Nodes explored: 77400, Frontier size: 20166
# Nodes explored: 77500, Frontier size: 20144
# Nodes explored: 77600, Frontier size: 20115
# Nodes explored: 77700, Frontier size: 20093
# Nodes explored: 77800, Frontier size: 20075
# Nodes explored: 77900, Frontier size: 20057
# Nodes explored: 78000, Frontier size: 20038
# Nodes explored: 78100, Frontier size: 20025
# Nodes explored: 78200, Frontier size: 19994
# Nodes explored: 78300, Frontier size: 19971
# Nodes explored: 78400, Frontier size: 19955
# Nodes explored: 78500, Frontier size: 19929
# Nodes explored: 78600, Frontier size: 19903
# Nodes explored: 78700, Frontier size: 19887
# Nodes explored: 78800, Frontier size: 19859
# Nodes explored: 78900, Frontier size: 19834
# Nodes explored: 79000, Frontier size: 19861
# Nodes explored: 79100, Frontier size: 19908
# Nodes explored: 79200, Frontier size: 19946
# Nodes explored: 79300, Frontier size: 19995
# Nodes explored: 79400, Frontier size: 20033
# Nodes explored: 79500, Frontier size: 20068
# Nodes explored: 79600, Frontier size: 20104
# Nodes explored: 79700, Frontier size: 20153
# Nodes explored: 79800, Frontier size: 20196
# Nodes explored: 79900, Frontier size: 20217
# Nodes explored: 80000, Frontier size: 20250
# Nodes explored: 80100, Frontier size: 20285
# Nodes explored: 80200, Frontier size: 20312
# Nodes explored: 80300, Frontier size: 20350
# Nodes explored: 80400, Frontier size: 20389
# Nodes explored: 80500, Frontier size: 20421
# Nodes explored: 80600, Frontier size: 20462
# Nodes explored: 80700, Frontier size: 20495
# Nodes explored: 80800, Frontier size: 20514
# Nodes explored: 80900, Frontier size: 20555
# Nodes explored: 81000, Frontier size: 20593
# Nodes explored: 81100, Frontier size: 20631
# Nodes explored: 81200, Frontier size: 20676
# Nodes explored: 81300, Frontier size: 20707
# Nodes explored: 81400, Frontier size: 20745
# Nodes explored: 81500, Frontier size: 20785
# Nodes explored: 81600, Frontier size: 20830
# Nodes explored: 81700, Frontier size: 20870
# Nodes explored: 81800, Frontier size: 20914
# Nodes explored: 81900, Frontier size: 20953
# Nodes explored: 82000, Frontier size: 20993
# Nodes explored: 82100, Frontier size: 21034
# Nodes explored: 82200, Frontier size: 21089
# Nodes explored: 82300, Frontier size: 21113
# Nodes explored: 82400, Frontier size: 21143
# Nodes explored: 82500, Frontier size: 21180
# Nodes explored: 82600, Frontier size: 21208
# Nodes explored: 82700, Frontier size: 21239
# Nodes explored: 82800, Frontier size: 21269
# Nodes explored: 82900, Frontier size: 21309
# Nodes explored: 83000, Frontier size: 21346
# Nodes explored: 83100, Frontier size: 21375
# Nodes explored: 83200, Frontier size: 21403
# Nodes explored: 83300, Frontier size: 21432
# Nodes explored: 83400, Frontier size: 21463
# Nodes explored: 83500, Frontier size: 21506
# Nodes explored: 83600, Frontier size: 21540
# Nodes explored: 83700, Frontier size: 21580
# Nodes explored: 83800, Frontier size: 21609
# Nodes explored: 83900, Frontier size: 21650
# Nodes explored: 84000, Frontier size: 21674
# Nodes explored: 84100, Frontier size: 21705
# Nodes explored: 84200, Frontier size: 21738
# Nodes explored: 84300, Frontier size: 21768
# Nodes explored: 84400, Frontier size: 21787
# Nodes explored: 84500, Frontier size: 21822
# Nodes explored: 84600, Frontier size: 21844
# Nodes explored: 84700, Frontier size: 21861
# Nodes explored: 84800, Frontier size: 21895
# Nodes explored: 84900, Frontier size: 21926
# Nodes explored: 85000, Frontier size: 21955
# Nodes explored: 85100, Frontier size: 21994
# Nodes explored: 85200, Frontier size: 22014
# Nodes explored: 85300, Frontier size: 22037
# Nodes explored: 85400, Frontier size: 22067
# Nodes explored: 85500, Frontier size: 22106
# Nodes explored: 85600, Frontier size: 22121
# Nodes explored: 85700, Frontier size: 22148
# Nodes explored: 85800, Frontier size: 22164
# Nodes explored: 85900, Frontier size: 22198
# Nodes explored: 86000, Frontier size: 22224
# Nodes explored: 86100, Frontier size: 22249
# Nodes explored: 86200, Frontier size: 22281
# Nodes explored: 86300, Frontier size: 22324
# Nodes explored: 86400, Frontier size: 22350
# Nodes explored: 86500, Frontier size: 22378
# Nodes explored: 86600, Frontier size: 22404
# Nodes explored: 86700, Frontier size: 22418
# Nodes explored: 86800, Frontier size: 22450
# Nodes explored: 86900, Frontier size: 22467
# Nodes explored: 87000, Frontier size: 22491
# Nodes explored: 87100, Frontier size: 22525
# Nodes explored: 87200, Frontier size: 22560
# Nodes explored: 87300, Frontier size: 22582
# Nodes explored: 87400, Frontier size: 22614
# Nodes explored: 87500, Frontier size: 22639
# Nodes explored: 87600, Frontier size: 22660
# Nodes explored: 87700, Frontier size: 22675
# Nodes explored: 87800, Frontier size: 22702
# Nodes explored: 87900, Frontier size: 22725
# Nodes explored: 88000, Frontier size: 22737
# Nodes explored: 88100, Frontier size: 22758
# Nodes explored: 88200, Frontier size: 22787
# Nodes explored: 88300, Frontier size: 22809
# Nodes explored: 88400, Frontier size: 22846
# Nodes explored: 88500, Frontier size: 22870
# Nodes explored: 88600, Frontier size: 22887
# Nodes explored: 88700, Frontier size: 22908
# Nodes explored: 88800, Frontier size: 22925
# Nodes explored: 88900, Frontier size: 22940
# Nodes explored: 89000, Frontier size: 22949
# Nodes explored: 89100, Frontier size: 22981
# Nodes explored: 89200, Frontier size: 22984
# Nodes explored: 89300, Frontier size: 22997
# Nodes explored: 89400, Frontier size: 23023
# Nodes explored: 89500, Frontier size: 23049
# Nodes explored: 89600, Frontier size: 23080
# Nodes explored: 89700, Frontier size: 23098
# Nodes explored: 89800, Frontier size: 23121
# Nodes explored: 89900, Frontier size: 23153
# Nodes explored: 90000, Frontier size: 23168
# Nodes explored: 90100, Frontier size: 23198
# Nodes explored: 90200, Frontier size: 23231
# Nodes explored: 90300, Frontier size: 23253
# Nodes explored: 90400, Frontier size: 23270
# Nodes explored: 90500, Frontier size: 23276
# Nodes explored: 90600, Frontier size: 23292
# Nodes explored: 90700, Frontier size: 23311
# Nodes explored: 90800, Frontier size: 23335
# Nodes explored: 90900, Frontier size: 23350
# Nodes explored: 91000, Frontier size: 23370
# Nodes explored: 91100, Frontier size: 23396
# Nodes explored: 91200, Frontier size: 23417
# Nodes explored: 91300, Frontier size: 23440
# Nodes explored: 91400, Frontier size: 23473
# Nodes explored: 91500, Frontier size: 23501
# Nodes explored: 91600, Frontier size: 23522
# Nodes explored: 91700, Frontier size: 23540
# Nodes explored: 91800, Frontier size: 23558
# Nodes explored: 91900, Frontier size: 23573
# Nodes explored: 92000, Frontier size: 23603
# Nodes explored: 92100, Frontier size: 23641
# Nodes explored: 92200, Frontier size: 23658
# Nodes explored: 92300, Frontier size: 23686
# Nodes explored: 92400, Frontier size: 23716
# Nodes explored: 92500, Frontier size: 23731
# Nodes explored: 92600, Frontier size: 23758
# Nodes explored: 92700, Frontier size: 23779
# Nodes explored: 92800, Frontier size: 23787
# Nodes explored: 92900, Frontier size: 23796
# Nodes explored: 93000, Frontier size: 23811
# Nodes explored: 93100, Frontier size: 23836
# Nodes explored: 93200, Frontier size: 23866
# Nodes explored: 93300, Frontier size: 23900
# Nodes explored: 93400, Frontier size: 23926
# Nodes explored: 93500, Frontier size: 23948
# Nodes explored: 93600, Frontier size: 23974
# Nodes explored: 93700, Frontier size: 23999
# Nodes explored: 93800, Frontier size: 24019
# Nodes explored: 93900, Frontier size: 24043
# Nodes explored: 94000, Frontier size: 24075
# Nodes explored: 94100, Frontier size: 24117
# Nodes explored: 94200, Frontier size: 24152
# Nodes explored: 94300, Frontier size: 24169
# Nodes explored: 94400, Frontier size: 24189
# Nodes explored: 94500, Frontier size: 24227
# Nodes explored: 94600, Frontier size: 24253
# Nodes explored: 94700, Frontier size: 24273
# Nodes explored: 94800, Frontier size: 24301
# Nodes explored: 94900, Frontier size: 24325
# Nodes explored: 95000, Frontier size: 24347
# Nodes explored: 95100, Frontier size: 24371
# Nodes explored: 95200, Frontier size: 24384
# Nodes explored: 95300, Frontier size: 24403
# Nodes explored: 95400, Frontier size: 24442
# Nodes explored: 95500, Frontier size: 24464
# Nodes explored: 95600, Frontier size: 24475
# Nodes explored: 95700, Frontier size: 24500
# Nodes explored: 95800, Frontier size: 24518
# Nodes explored: 95900, Frontier size: 24548
# Nodes explored: 96000, Frontier size: 24575
# Nodes explored: 96100, Frontier size: 24605
# Nodes explored: 96200, Frontier size: 24630
# Nodes explored: 96300, Frontier size: 24647
# Nodes explored: 96400, Frontier size: 24653
# Nodes explored: 96500, Frontier size: 24681
# Nodes explored: 96600, Frontier size: 24696
# Nodes explored: 96700, Frontier size: 24705
# ...
# Nodes explored: 146300, Frontier size: 17360
# Nodes explored: 146400, Frontier size: 17322
# Nodes explored: 146500, Frontier size: 17279
# Nodes explored: 146600, Frontier size: 17224
# Nodes explored: 146700, Frontier size: 17192
# Nodes explored: 146800, Frontier size: 17149
# Nodes explored: 146900, Frontier size: 17107
# Nodes explored: 147000, Frontier size: 17072
# Nodes explored: 147100, Frontier size: 17046
# Nodes explored: 147200, Frontier size: 17003
# Nodes explored: 147300, Frontier size: 16970
# Nodes explored: 147400, Frontier size: 16921
# Nodes explored: 147500, Frontier size: 16879
# Nodes explored: 147600, Frontier size: 16824
# Nodes explored: 147700, Frontier size: 16782
# Nodes explored: 147800, Frontier size: 16736
# Nodes explored: 147900, Frontier size: 16698
# Nodes explored: 148000, Frontier size: 16656
# Nodes explored: 148100, Frontier size: 16609
# Nodes explored: 148200, Frontier size: 16566
# Nodes explored: 148300, Frontier size: 16523
# Nodes explored: 148400, Frontier size: 16474
# Nodes explored: 148500, Frontier size: 16428
# Nodes explored: 148600, Frontier size: 16381
# Nodes explored: 148700, Frontier size: 16341
# Nodes explored: 148800, Frontier size: 16301
# Nodes explored: 148900, Frontier size: 16267
# Nodes explored: 149000, Frontier size: 16237
# Nodes explored: 149100, Frontier size: 16174
# Nodes explored: 149200, Frontier size: 16141
# Nodes explored: 149300, Frontier size: 16109
# Nodes explored: 149400, Frontier size: 16072
# Nodes explored: 149500, Frontier size: 16033
# Nodes explored: 149600, Frontier size: 15990
# Nodes explored: 149700, Frontier size: 15948
# Nodes explored: 149800, Frontier size: 15917
# Nodes explored: 149900, Frontier size: 15872
# Nodes explored: 150000, Frontier size: 15810
# Nodes explored: 150100, Frontier size: 15764
# Nodes explored: 150200, Frontier size: 15710
# Nodes explored: 150300, Frontier size: 15660
# Nodes explored: 150400, Frontier size: 15617
# Nodes explored: 150500, Frontier size: 15562
# Nodes explored: 150600, Frontier size: 15508
# Nodes explored: 150700, Frontier size: 15463
# Nodes explored: 150800, Frontier size: 15419
# Nodes explored: 150900, Frontier size: 15376
# Nodes explored: 151000, Frontier size: 15347
# Nodes explored: 151100, Frontier size: 15292
# Nodes explored: 151200, Frontier size: 15254
# Nodes explored: 151300, Frontier size: 15208
# Nodes explored: 151400, Frontier size: 15165
# Nodes explored: 151500, Frontier size: 15133
# Nodes explored: 151600, Frontier size: 15084
# Nodes explored: 151700, Frontier size: 15046
# Nodes explored: 151800, Frontier size: 14996
# Nodes explored: 151900, Frontier size: 14953
# Nodes explored: 152000, Frontier size: 14897
# Nodes explored: 152100, Frontier size: 14847
# Nodes explored: 152200, Frontier size: 14802
# Nodes explored: 152300, Frontier size: 14759
# Nodes explored: 152400, Frontier size: 14703
# Nodes explored: 152500, Frontier size: 14653
# Nodes explored: 152600, Frontier size: 14606
# Nodes explored: 152700, Frontier size: 14568
# Nodes explored: 152800, Frontier size: 14535
# Nodes explored: 152900, Frontier size: 14487
# Nodes explored: 153000, Frontier size: 14440
# Nodes explored: 153100, Frontier size: 14381
# Nodes explored: 153200, Frontier size: 14335
# Nodes explored: 153300, Frontier size: 14283
# Nodes explored: 153400, Frontier size: 14226
# Nodes explored: 153500, Frontier size: 14175
# Nodes explored: 153600, Frontier size: 14122
# Nodes explored: 153700, Frontier size: 14076
# Nodes explored: 153800, Frontier size: 14025
# Nodes explored: 153900, Frontier size: 13963
# Nodes explored: 154000, Frontier size: 13916
# Nodes explored: 154100, Frontier size: 13872
# Nodes explored: 154200, Frontier size: 13828
# Nodes explored: 154300, Frontier size: 13791
# Nodes explored: 154400, Frontier size: 13747
# Nodes explored: 154500, Frontier size: 13688
# Nodes explored: 154600, Frontier size: 13641
# Nodes explored: 154700, Frontier size: 13582
# Nodes explored: 154800, Frontier size: 13538
# Nodes explored: 154900, Frontier size: 13480
# Nodes explored: 155000, Frontier size: 13433
# Nodes explored: 155100, Frontier size: 13376
# Nodes explored: 155200, Frontier size: 13321
# Nodes explored: 155300, Frontier size: 13279
# Nodes explored: 155400, Frontier size: 13225
# Nodes explored: 155500, Frontier size: 13176
# Nodes explored: 155600, Frontier size: 13131
# Nodes explored: 155700, Frontier size: 13073
# Nodes explored: 155800, Frontier size: 13011
# Nodes explored: 155900, Frontier size: 12962
# Nodes explored: 156000, Frontier size: 12911
# Nodes explored: 156100, Frontier size: 12863
# Nodes explored: 156200, Frontier size: 12800
# Nodes explored: 156300, Frontier size: 12755
# Nodes explored: 156400, Frontier size: 12706
# Nodes explored: 156500, Frontier size: 12649
# Nodes explored: 156600, Frontier size: 12595
# Nodes explored: 156700, Frontier size: 12545
# Nodes explored: 156800, Frontier size: 12492
# Nodes explored: 156900, Frontier size: 12431
# Nodes explored: 157000, Frontier size: 12373
# Nodes explored: 157100, Frontier size: 12312
# Nodes explored: 157200, Frontier size: 12273
# Nodes explored: 157300, Frontier size: 12204
# Nodes explored: 157400, Frontier size: 12143
# Nodes explored: 157500, Frontier size: 12086
# Nodes explored: 157600, Frontier size: 12039
# Nodes explored: 157700, Frontier size: 11985
# Nodes explored: 157800, Frontier size: 11917
# Nodes explored: 157900, Frontier size: 11866
# Nodes explored: 158000, Frontier size: 11808
# Nodes explored: 158100, Frontier size: 11751
# Nodes explored: 158200, Frontier size: 11700
# Nodes explored: 158300, Frontier size: 11641
# Nodes explored: 158400, Frontier size: 11581
# Nodes explored: 158500, Frontier size: 11518
# Nodes explored: 158600, Frontier size: 11466
# Nodes explored: 158700, Frontier size: 11403
# Nodes explored: 158800, Frontier size: 11347
# Nodes explored: 158900, Frontier size: 11285
# Nodes explored: 159000, Frontier size: 11224
# Nodes explored: 159100, Frontier size: 11164
# Nodes explored: 159200, Frontier size: 11116
# Nodes explored: 159300, Frontier size: 11059
# Nodes explored: 159400, Frontier size: 10996
# Nodes explored: 159500, Frontier size: 10941
# Nodes explored: 159600, Frontier size: 10876
# Nodes explored: 159700, Frontier size: 10817
# Nodes explored: 159800, Frontier size: 10754
# Nodes explored: 159900, Frontier size: 10691
# Nodes explored: 160000, Frontier size: 10621
# Nodes explored: 160100, Frontier size: 10565
# Nodes explored: 160200, Frontier size: 10505
# Nodes explored: 160300, Frontier size: 10440
# Nodes explored: 160400, Frontier size: 10373
# Nodes explored: 160500, Frontier size: 10303
# Nodes explored: 160600, Frontier size: 10239
# Nodes explored: 160700, Frontier size: 10166
# Nodes explored: 160800, Frontier size: 10096
# Nodes explored: 160900, Frontier size: 10031
# Nodes explored: 161000, Frontier size: 9966
# Nodes explored: 161100, Frontier size: 9926
# Nodes explored: 161200, Frontier size: 9898
# Nodes explored: 161300, Frontier size: 9901
# Nodes explored: 161400, Frontier size: 9904
# Nodes explored: 161500, Frontier size: 9899
# Nodes explored: 161600, Frontier size: 9893
# Nodes explored: 161700, Frontier size: 9888
# Nodes explored: 161800, Frontier size: 9873
# Nodes explored: 161900, Frontier size: 9862
# Nodes explored: 162000, Frontier size: 9839
# Nodes explored: 162100, Frontier size: 9824
# Nodes explored: 162200, Frontier size: 9815
# Nodes explored: 162300, Frontier size: 9797
# Nodes explored: 162400, Frontier size: 9789
# Nodes explored: 162500, Frontier size: 9781
# Nodes explored: 162600, Frontier size: 9765
# Nodes explored: 162700, Frontier size: 9753
# Nodes explored: 162800, Frontier size: 9734
# Nodes explored: 162900, Frontier size: 9718
# Nodes explored: 163000, Frontier size: 9707
# Nodes explored: 163100, Frontier size: 9695
# Nodes explored: 163200, Frontier size: 9683
# Nodes explored: 163300, Frontier size: 9696
# Nodes explored: 163400, Frontier size: 9676
# Nodes explored: 163500, Frontier size: 9656
# Nodes explored: 163600, Frontier size: 9636
# Nodes explored: 163700, Frontier size: 9620
# Nodes explored: 163800, Frontier size: 9606
# Nodes explored: 163900, Frontier size: 9591
# Nodes explored: 164000, Frontier size: 9575
# Nodes explored: 164100, Frontier size: 9549
# Nodes explored: 164200, Frontier size: 9529
# Nodes explored: 164300, Frontier size: 9518
# Nodes explored: 164400, Frontier size: 9494
# Nodes explored: 164500, Frontier size: 9467
# Nodes explored: 164600, Frontier size: 9454
# Nodes explored: 164700, Frontier size: 9432
# Nodes explored: 164800, Frontier size: 9422
# Nodes explored: 164900, Frontier size: 9386
# Nodes explored: 165000, Frontier size: 9363
# Nodes explored: 165100, Frontier size: 9332
# Nodes explored: 165200, Frontier size: 9306
# Nodes explored: 165300, Frontier size: 9271
# Nodes explored: 165400, Frontier size: 9249
# Nodes explored: 165500, Frontier size: 9218
# Nodes explored: 165600, Frontier size: 9191
# Nodes explored: 165700, Frontier size: 9163
# Nodes explored: 165800, Frontier size: 9140
# Nodes explored: 165900, Frontier size: 9115
# Nodes explored: 166000, Frontier size: 9084
# Nodes explored: 166100, Frontier size: 9057
# Nodes explored: 166200, Frontier size: 9036
# Nodes explored: 166300, Frontier size: 9003
# Nodes explored: 166400, Frontier size: 8980
# Nodes explored: 166500, Frontier size: 8952
# Nodes explored: 166600, Frontier size: 8921
# Nodes explored: 166700, Frontier size: 8896
# Nodes explored: 166800, Frontier size: 8874
# Nodes explored: 166900, Frontier size: 8838
# Nodes explored: 167000, Frontier size: 8811
# Nodes explored: 167100, Frontier size: 8775
# Nodes explored: 167200, Frontier size: 8737
# Nodes explored: 167300, Frontier size: 8712
# Nodes explored: 167400, Frontier size: 8676
# Nodes explored: 167500, Frontier size: 8638
# Nodes explored: 167600, Frontier size: 8596
# Nodes explored: 167700, Frontier size: 8558
# Nodes explored: 167800, Frontier size: 8527
# Nodes explored: 167900, Frontier size: 8489
# Nodes explored: 168000, Frontier size: 8455
# Nodes explored: 168100, Frontier size: 8423
# Nodes explored: 168200, Frontier size: 8377
# Nodes explored: 168300, Frontier size: 8335
# Nodes explored: 168400, Frontier size: 8295
# Nodes explored: 168500, Frontier size: 8282
# Nodes explored: 168600, Frontier size: 8258
# Nodes explored: 168700, Frontier size: 8222
# Nodes explored: 168800, Frontier size: 8194
# Nodes explored: 168900, Frontier size: 8159
# Nodes explored: 169000, Frontier size: 8128
# Nodes explored: 169100, Frontier size: 8111
# Nodes explored: 169200, Frontier size: 8074
# Nodes explored: 169300, Frontier size: 8048
# Nodes explored: 169400, Frontier size: 8013
# Nodes explored: 169500, Frontier size: 7963
# Nodes explored: 169600, Frontier size: 7934
# Nodes explored: 169700, Frontier size: 7888
# Nodes explored: 169800, Frontier size: 7841
# Nodes explored: 169900, Frontier size: 7790
# Nodes explored: 170000, Frontier size: 7744
# Nodes explored: 170100, Frontier size: 7707
# Nodes explored: 170200, Frontier size: 7683
# Nodes explored: 170300, Frontier size: 7651
# Nodes explored: 170400, Frontier size: 7607
# Nodes explored: 170500, Frontier size: 7586
# Nodes explored: 170600, Frontier size: 7548
# Nodes explored: 170700, Frontier size: 7502
# Nodes explored: 170800, Frontier size: 7449
# Nodes explored: 170900, Frontier size: 7401
# Nodes explored: 171000, Frontier size: 7357
# Nodes explored: 171100, Frontier size: 7294
# Nodes explored: 171200, Frontier size: 7242
# Nodes explored: 171300, Frontier size: 7178
# Nodes explored: 171400, Frontier size: 7110
# Nodes explored: 171500, Frontier size: 7052
# Nodes explored: 171600, Frontier size: 6996
# Nodes explored: 171700, Frontier size: 6925
# Nodes explored: 171800, Frontier size: 6865
# Nodes explored: 171900, Frontier size: 6791
# Nodes explored: 172000, Frontier size: 6721
# Nodes explored: 172100, Frontier size: 6650
# Nodes explored: 172200, Frontier size: 6588
# Nodes explored: 172300, Frontier size: 6538
# Nodes explored: 172400, Frontier size: 6457
# Nodes explored: 172500, Frontier size: 6388
# Nodes explored: 172600, Frontier size: 6330
# Nodes explored: 172700, Frontier size: 6268
# Nodes explored: 172800, Frontier size: 6200
# Nodes explored: 172900, Frontier size: 6134
# Nodes explored: 173000, Frontier size: 6071
# Nodes explored: 173100, Frontier size: 6003
# Nodes explored: 173200, Frontier size: 5942
# Nodes explored: 173300, Frontier size: 5882
# Nodes explored: 173400, Frontier size: 5815
# Nodes explored: 173500, Frontier size: 5744
# Nodes explored: 173600, Frontier size: 5675
# Nodes explored: 173700, Frontier size: 5609
# Nodes explored: 173800, Frontier size: 5538
# Nodes explored: 173900, Frontier size: 5456
# Nodes explored: 174000, Frontier size: 5398
# Nodes explored: 174100, Frontier size: 5323
# Nodes explored: 174200, Frontier size: 5244
# Nodes explored: 174300, Frontier size: 5169
# Nodes explored: 174400, Frontier size: 5098
# Nodes explored: 174500, Frontier size: 5025
# Nodes explored: 174600, Frontier size: 4952
# Nodes explored: 174700, Frontier size: 4876
# Nodes explored: 174800, Frontier size: 4811
# Nodes explored: 174900, Frontier size: 4750
# Nodes explored: 175000, Frontier size: 4673
# Nodes explored: 175100, Frontier size: 4599
# Nodes explored: 175200, Frontier size: 4519
# Nodes explored: 175300, Frontier size: 4436
# Nodes explored: 175400, Frontier size: 4360
# Nodes explored: 175500, Frontier size: 4289
# Nodes explored: 175600, Frontier size: 4216
# Nodes explored: 175700, Frontier size: 4143
# Nodes explored: 175800, Frontier size: 4065
# Nodes explored: 175900, Frontier size: 3993
# Nodes explored: 176000, Frontier size: 3912
# Nodes explored: 176100, Frontier size: 3840
# Nodes explored: 176200, Frontier size: 3773
# Nodes explored: 176300, Frontier size: 3693
# Nodes explored: 176400, Frontier size: 3617
# Nodes explored: 176500, Frontier size: 3538
# Nodes explored: 176600, Frontier size: 3464
# Nodes explored: 176700, Frontier size: 3391
# Nodes explored: 176800, Frontier size: 3318
# Nodes explored: 176900, Frontier size: 3245
# Nodes explored: 177000, Frontier size: 3170
# Nodes explored: 177100, Frontier size: 3088
# Nodes explored: 177200, Frontier size: 3017
# Nodes explored: 177300, Frontier size: 2941
# Nodes explored: 177400, Frontier size: 2860
# Nodes explored: 177500, Frontier size: 2775
# Nodes explored: 177600, Frontier size: 2699
# Nodes explored: 177700, Frontier size: 2618
# Nodes explored: 177800, Frontier size: 2538
# Nodes explored: 177900, Frontier size: 2459
# Nodes explored: 178000, Frontier size: 2372
# Nodes explored: 178100, Frontier size: 2299
# Nodes explored: 178200, Frontier size: 2209
# Nodes explored: 178300, Frontier size: 2126
# Nodes explored: 178400, Frontier size: 2066
# Nodes explored: 178500, Frontier size: 2019
# Nodes explored: 178600, Frontier size: 1963
# Nodes explored: 178700, Frontier size: 1917
# Nodes explored: 178800, Frontier size: 1858
# Nodes explored: 178900, Frontier size: 1802
# Nodes explored: 179000, Frontier size: 1742
# Nodes explored: 179100, Frontier size: 1690
# Nodes explored: 179200, Frontier size: 1632
# Nodes explored: 179300, Frontier size: 1574
# Nodes explored: 179400, Frontier size: 1510
# Nodes explored: 179500, Frontier size: 1444
# Nodes explored: 179600, Frontier size: 1383
# Nodes explored: 179700, Frontier size: 1322
# Nodes explored: 179800, Frontier size: 1259
# Nodes explored: 179900, Frontier size: 1197
# Nodes explored: 180000, Frontier size: 1133
# Nodes explored: 180100, Frontier size: 1073
# Nodes explored: 180200, Frontier size: 1030
# Nodes explored: 180300, Frontier size: 976
# Nodes explored: 180400, Frontier size: 904
# Nodes explored: 180500, Frontier size: 830
# Nodes explored: 180600, Frontier size: 751
# Nodes explored: 180700, Frontier size: 674
# Nodes explored: 180800, Frontier size: 595
# Nodes explored: 180900, Frontier size: 510
# Nodes explored: 181000, Frontier size: 423
# Nodes explored: 181100, Frontier size: 330
# Nodes explored: 181200, Frontier size: 238
# Nodes explored: 181300, Frontier size: 138
#
# solution found!
# Solution length: 31 moves
# Nodes explored: 181378
# Nodes generated: 181440
# Time taken: 3.3815 seconds
#
# Puzzle solved successfully.
# Use option 4 to view detailed solution.
#
# Menu options:
# 1. Load puzzle from file
# 2. Manual puzzle input
# 3. Solve current puzzle
# 4. View solution details
# 5. Exit
# Enter choice (1-5):  5
# Thank you for using the 8-puzzle solver. Goodbye.
